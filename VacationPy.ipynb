# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      jamestown  42.0970  -79.2353    277.92        70          20
# 1        1  pontian kecil   1.4801  103.3899    299.33        89           7
# 2        2           tura  25.5198   90.2201    295.35        40           7
# 3        3           hilo  19.7297 -155.0900    295.53        93          40
# 4        4   norman wells  65.2820 -126.8329    270.17        93         100
#
#    Wind Speed Country        Date
# 0        0.00      US  1680017058
# 1        3.75      MY  1680017064
# 2        1.91      IN  1680017064
# 3        2.24      US  1680016970
# 4        0.00      CA  1680017064

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map_plot = city_data_df.hvplot.points("Lng","Lat", geo = True, tiles="OSM", \
                                         frame_width=700, frame_height=500, \
                                         size="Humidity", scale=0.5, color="City")


# Display the map
city_map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
final_city = city_data_df.loc[(city_data_df["Max Temp"]  > 270) & (city_data_df["Max Temp"] < 290) & (city_data_df["Wind Speed"] < 5) & (city_data_df["Cloudiness"] == 0)]




  



 # Display sample data
final_city
# Out:
#      City_ID                       City      Lat       Lng  Max Temp  \
# 75        75                     kodiak  57.7900 -152.4072    270.88
# 83        83                      atasu  48.6814   71.6433    276.30
# 128      128                       hami  42.8000   93.4500    288.38
# 177      177                     alpena  45.0617  -83.4327    276.29
# 208      208              prince rupert  54.3161 -130.3201    277.98
# 220      220                  ketchikan  55.3422 -131.6461    276.41
# 230      230                    karakol  42.4907   78.3936    280.29
# 244      244                   hamilton  39.1834  -84.5333    283.38
# 245      245                      sitka  57.0531 -135.3300    276.09
# 269      269                   vetlanda  57.4289   15.0776    276.51
# 291      291                  belyy yar  53.6039   91.3903    279.18
# 330      330                     hohhot  40.8106  111.6522    275.31
# 368      368               saint george  37.1041 -113.5841    278.68
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = final_city.copy()
hotel_df = hotel_df[["City","Country","Lat","Lng","Humidity"]]


# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                           City Country      Lat       Lng  Humidity Hotel Name
# 75                      kodiak      US  57.7900 -152.4072        86
# 83                       atasu      KZ  48.6814   71.6433        73
# 128                       hami      CN  42.8000   93.4500        14
# 177                     alpena      US  45.0617  -83.4327        41
# 208              prince rupert      CA  54.3161 -130.3201        80
# 220                  ketchikan      US  55.3422 -131.6461        65
# 230                    karakol      KG  42.4907   78.3936        41
# 244                   hamilton      US  39.1834  -84.5333        63
# 245                      sitka      US  57.0531 -135.3300        70
# 269                   vetlanda      SE  57.4289   15.0776        37
# 291                  belyy yar      RU  53.6039   91.3903        72
# 330                     hohhot      CN  40.8106  111.6522        32
# 368               saint george      US  37.1041 -113.5841        43
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 5
apiKey = geoapify_key
params = {
    "limit":limit,
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    long = hotel_df.loc[index, "Lng"]
    lat = hotel_df.loc[index, "Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{long},{lat},{radius}'
    params["bias"] = f'proximity:{long},{lat}'
    params["categories"] = f'accomodation.hotel'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# kodiak - nearest hotel: No hotel found
# atasu - nearest hotel: No hotel found
# hami - nearest hotel: No hotel found
# alpena - nearest hotel: No hotel found
# prince rupert - nearest hotel: No hotel found
# ketchikan - nearest hotel: No hotel found
# karakol - nearest hotel: No hotel found
# hamilton - nearest hotel: No hotel found
# sitka - nearest hotel: No hotel found
# vetlanda - nearest hotel: No hotel found
# belyy yar - nearest hotel: No hotel found
# hohhot - nearest hotel: No hotel found
# saint george - nearest hotel: No hotel found
# allonnes - nearest hotel: No hotel found
# yinchuan - nearest hotel: No hotel found
# west wendover - nearest hotel: No hotel found
# gravdal - nearest hotel: No hotel found
# petropavlovsk-kamchatskiy - nearest hotel: No hotel found
# kingman - nearest hotel: No hotel found
# erenhot - nearest hotel: No hotel found
# aksu - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
plot_map_hotel = hotel_df.hvplot.points("Lng","Lat", geo = True, tiles="OSM", \
                                         frame_width=700, frame_height=500, \
                                         size="Humidity", scale=0.5, color="City", \
                                          hover_columns = ["Hotel Name","Country"]
                                       )

# Display the map
plot_map_hotel
# Out:
# WARNING:param.main: hover_columns option not found for points plot with bokeh; similar options include: ['hover_color', 'hover_line_dash', 'hover_line_color']
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)
